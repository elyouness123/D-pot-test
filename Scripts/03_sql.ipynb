# %% [markdown]
# # Notebook 3 : SQL

# %%
# Décommenter la ligne suivante pour installer ibis
# %pip install 'ibis-framework[sqlite]'
# Out:
# Collecting ibis-framework[sqlite]
#   Downloading ibis_framework-12.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting atpublic>=2.3 (from ibis-framework[sqlite])
#   Downloading atpublic-7.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting parsy>=2 (from ibis-framework[sqlite])
#   Downloading parsy-2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (2.9.0.post0)
# Collecting sqlglot!=26.32.0,>=23.4 (from ibis-framework[sqlite])
#   Downloading sqlglot-30.4.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: toolz>=0.11 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (4.15.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (2025.3)
# Requirement already satisfied: numpy<3,>=1.23.2 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (2.4.2)
# Requirement already satisfied: packaging>=21.3 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (25.0)
# Requirement already satisfied: pandas<4,>=1.5.3 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (2.3.3)
# Collecting pyarrow-hotfix>=0.4 (from ibis-framework[sqlite])
#   Downloading pyarrow_hotfix-0.7-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pyarrow>=10.0.1 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (22.0.0)
# Requirement already satisfied: regex>=2021.7.6 in /opt/python/lib/python3.13/site-packages (from ibis-framework[sqlite]) (2026.1.15)
# Collecting rich>=12.4.4 (from ibis-framework[sqlite])
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas<4,>=1.5.3->ibis-framework[sqlite]) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->ibis-framework[sqlite]) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.4.4->ibis-framework[sqlite])
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/python/lib/python3.13/site-packages (from rich>=12.4.4->ibis-framework[sqlite]) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.4.4->ibis-framework[sqlite])
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading ibis_framework-12.0.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.3 MB/s  0:00:00
# Downloading atpublic-7.0.0-py3-none-any.whl (6.4 kB)
# Downloading parsy-2.2-py3-none-any.whl (9.5 kB)
# Downloading pyarrow_hotfix-0.7-py3-none-any.whl (7.9 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading sqlglot-30.4.2-py3-none-any.whl (670 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.9/670.9 kB 7.3 MB/s  0:00:00
# Installing collected packages: sqlglot, pyarrow-hotfix, parsy, mdurl, atpublic, markdown-it-py, ibis-framework, rich
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [rich]7/8 [rich]framework]
# Successfully installed atpublic-7.0.0 ibis-framework-12.0.0 markdown-it-py-4.0.0 mdurl-0.1.2 parsy-2.2 pyarrow-hotfix-0.7 rich-14.3.3 sqlglot-30.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlite3

import pandas as pd
import ibis

from ibis import _

ibis.options.interactive = True

query_tables = "SELECT name FROM sqlite_master WHERE type='table'"

# %% [markdown]
# ## STAR

# %% [markdown]
# Nous considérons les données des stations de vélos en libre service [STAR](https://www.star.fr/) de Rennes Métropole. Une copie de la base SQLite est disponible dans le fichier `star.db`. Nous utilisons d'abord Pandas pour répondre aux questions, puis Ibis.

# %% [markdown]
# 1. Se connecter à la base de données et afficher la liste des tables à l'aide de la fonction `read_sql` de Pandas et de la requête `query_tables`.

# %%
con =sqlite3.connect("/home/onyxia/work/D-pot-test/DATA/star.db")

pd.read_sql(query_tables, con)
# Out:
#         name
# 0  Topologie
# 1       Etat

# %% [markdown]
# 2. Récupérer le contenu de la table `Etat` dans un dataframe et afficher la liste des variables disponibles. Même question pour la table `Topologie`.

# %%
etat = pd.read_sql("SELECT * \
                   FROM Etat",
                    con)
etat
# Out:
#     id                nom   latitude  longitude               etat  \
# 0    1         République  48.110026  -1.678037  En fonctionnement
# 1    2             Mairie  48.111624  -1.678757  En fonctionnement
# 2    3      Champ Jacquet  48.112764  -1.680062  En fonctionnement
# 3   10   Musée Beaux-Arts  48.109601  -1.674080  En fonctionnement
# 4   12                TNB  48.107748  -1.673711  En fonctionnement
# ..  ..                ...        ...        ...                ...
# 78  62         Clemenceau  48.093292  -1.674116  En fonctionnement
# 79  66  Bréquigny Piscine  48.089621  -1.690242  En fonctionnement
# 80  69    Champs Manceaux  48.091114  -1.682284  En fonctionnement
# 81  85       La Courrouze  48.098909  -1.694523  En fonctionnement
# 82  86          Armorique  48.129754  -1.675788  En fonctionnement
#
#     nb_emplacements  emplacements_disponibles  velos_disponibles  \
# 0                30                        25                  5
# 1                24                         6                 18
# 2                24                         8                 16
# 3                16                         4                 12
# 4                28                        16                 12
# ..              ...                       ...                ...
# 78               22                        18                  4
# 79               24                        19                  5
# 80               18                        12                  6
# 81               20                        16                  4
# 82               24                        11                 13
#
#             date                 data
# 0   1.524646e+09  2018-04-25 08:47:04
# 1   1.524646e+09  2018-04-25 08:47:04
# 2   1.524646e+09  2018-04-25 08:47:04
# 3   1.524646e+09  2018-04-25 08:47:04
# 4   1.524646e+09  2018-04-25 08:47:04
# ..           ...                  ...
# 78  1.524646e+09  2018-04-25 08:47:04
# 79  1.524646e+09  2018-04-25 08:47:04
# 80  1.524646e+09  2018-04-25 08:47:04
# 81  1.524646e+09  2018-04-25 08:47:04
# 82  1.524646e+09  2018-04-25 08:47:04
#
# [83 rows x 10 columns]

# %% [markdown]
# 3. Sélectionner l'identifiant `id`, le nom `nom` et l'identifiant de la station la plus proche `id_proche_1` depuis la table `Topologie`.

# %% [markdown]
# 4. Faire une jointure sur la table précédente pour créer une table qui contient la liste des stations avec l'identifiant, le nom et le nom de la station la plus proche associée à l'identifiant `id_proche_1`. Les variables utilisées comme clés sont différents, penser à utiliser les arguments `left_on` et `right_on` de la méthode `merge`.

# %% [markdown]
# 5. Ajouter à la table précédente la distance entre la station et la station la plus proche.

# %% [markdown]
# 6. Créer une table avec le nom des trois stations les plus proches du point GPS *(48.1179151,-1.7028661)* classées par ordre de distance et le nombre de vélos disponibles dans ces stations.

# %% [markdown]
# 7. Reprendre les questions précédentes en utilisant le module `ibis`. Pour les jointures, utiliser la méthode `left_join`.

# %% [markdown]
# 8. (*Bonus*) Écrire des requêtes SQL pour obtenir les résultats demandés dans les questions 3 à 6. La fonction `to_sql` pourra être utilisée pour de l'aide.

# %% [markdown]
# ## Musique

# %% [markdown]
# Le dépôt GitHub [lerocha/chinook-database](https://github.com/lerocha/chinook-database) met à disposition des bases de données de bibliothèques musicales. Une copie de la base SQLite est disponible dans le fichier `chinook.db`.

# %% [markdown]
# 1. Utiliser le module `ibis` pour vous connecter à la base de données et explorer les tables formant le jeu de données pour le découvrir. En particulier, remarquer comment les tables `Playlist`, `PlaylistTrack` et `Track` sont liées entre elles.

# %% [markdown]
# 2. Quelles sont les playlists qui contiennent le plus de pistes ?

# %% [markdown]
# 3. Construire une table contenant les informations suivantes sur la playlist `Classical` : le titre de chaque piste ainsi que le titre de l'album dont cette piste est tirée.

# %% [markdown]
# 4. (*Bonus*) Écrire une requête SQL donnant le résultat de la question précédente. La fonction `to_sql` pourra être utilisée pour de l'aide.
